# %% [markdown]
# # InstColorization fine-tuning 시도
#
# - paper: Instance-aware Image Colorization (CVPR 2020)
# - code: https://github.com/ericsujw/InstColorization
#
# 한국 음식 샘플 이미지(`color_image_sample_jpg`)로 fine-tuning을 시도한 기록이다.
# 원저자의 사전학습 weight 배포 URL이 삭제되어 학습을 완료하지 못했고, 진행 과정과 실패 지점을 그대로 남긴다.

# %%
# !pip install -U torch==1.5 torchvision==0.6 -f https://download.pytorch.org/whl/cu101/torch_stable.html
# !pip install cython pyyaml==5.1
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# !pip install dominate==2.4.0
# !pip install detectron2==0.1.2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/index.html

# %%
# !pip install visdom

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd data

# %%
# !git clone https://github.com/ericsujw/InstColorization

# %%
cd InstColorization

# %%
# !sh scripts/install.sh

# %% [markdown]
# 사전학습 checkpoint 다운로드 단계. 원저자가 올려 둔 `checkpoints.zip` URL이 삭제되어 실패했고,
# 구글링으로 찾은 사본으로 `download.py`의 URL을 바꿔 재시도했지만 일부 weight만 받을 수 있었다.

# %%
# !sh scripts/download_model.sh

# %% [markdown]
# `scripts/prepare_train_box.sh`와 `scripts/train.sh`의 `DATASET_DIR`은 한국 음식 샘플 이미지 폴더
# (`data/color_image_sample_jpg`)로 바꿔 실행했다. 아래 단계는 detectron2로 개체 bbox를 미리 뽑아 둔다.

# %%
# !sh scripts/prepare_train_box.sh

# %%
# !ls ../color_image_sample_jpg_bbox

# %%
# !visdom -port 8098

# %% [markdown]
# Stage 1(full image colorization)은 `checkpoints/siggraph_retrained/latest_net_G.pth`를 불러오며 시작하는데,
# 위에서 완전한 weight를 받지 못해 이 지점에서 중단됐다.

# %%
# !sh scripts/train.sh

# %%
# python test_fusion.py --name test_fusion --sample_p 1.0 --model fusion --fineSize 256 --test_img_dir example --results_img_dir results
